# %%
import pandas as pd

# %%
cd E:\ml_projects\movie_recommender_system\ml-100k
# Out:
# E:\ml_projects\movie_recommender_system\ml-100k

# %%
r_cols=['user_id','movie_id','rating']

# %%
ratings=pd.read_csv('u.data',sep='\t',names=r_cols,usecols=range(3))

# %%
m_cols=['movie_id','title']
movies=pd.read_csv('u.item',sep='|',names=m_cols,usecols=range(2),encoding="ISO-8859-1")
ratings=pd.merge(movies,ratings)

# %%
ratings.head()
# Out:
#    movie_id             title  user_id  rating
# 0         1  Toy Story (1995)      308       4
# 1         1  Toy Story (1995)      287       5
# 2         1  Toy Story (1995)      148       4
# 3         1  Toy Story (1995)      280       4
# 4         1  Toy Story (1995)       66       3

# %%
userRatings=ratings.pivot_table(index=['user_id'],columns=['title'],values='rating')
userRatings
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# 6                              NaN           NaN                    NaN
# 7                              NaN           NaN                    NaN
# 8                              NaN           NaN                    NaN
# 9                              NaN           NaN                    NaN
# 10                             NaN           NaN                    NaN
# 11                             NaN           NaN                    NaN
# ...

# %%
corrMatrix=userRatings.corr()
corrMatrix.head()
corrMatrix=userRatings.corr(method='pearson',min_periods=100)
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        NaN           NaN
# 1-900 (1994)                                     NaN           NaN
# 101 Dalmatians (1996)                            NaN           NaN
# 12 Angry Men (1957)                              NaN           NaN
# 187 (1997)                                       NaN           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)                    NaN                  NaN
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                        1.0                  NaN
# 12 Angry Men (1957)                          NaN                  1.0
# 187 (1997)                                   NaN                  NaN
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %%
myRatings=userRatings.loc[0].dropna()        #myRatings are ratings of user 0
myRatings
# Out:
# title
# Empire Strikes Back, The (1980)    5.0
# Gone with the Wind (1939)          1.0
# Star Wars (1977)                   5.0
# Name: 0, dtype: float64

# %%
similarCandidates=pd.Series()
for i in range(0,len(myRatings.index)):
    print("Adding similar movies to "+myRatings.index[i])
    sims=corrMatrix[myRatings.index[i]].dropna()
    sims=sims.map(lambda x: x*myRatings[i])
    similarCandidates=similarCandidates.append(sims)
print("Sorting ...")
similarCandidates.sort_values(inplace=True,ascending=False)
print(similarCandidates.head(10))
# Out:
# Adding similar movies to Empire Strikes Back, The (1980)
# Adding similar movies to Gone with the Wind (1939)
# Adding similar movies to Star Wars (1977)
# Sorting ...
# Empire Strikes Back, The (1980)                       5.000000
# Star Wars (1977)                                      5.000000
# Empire Strikes Back, The (1980)                       3.741763
# Star Wars (1977)                                      3.741763
# Return of the Jedi (1983)                             3.606146
# Return of the Jedi (1983)                             3.362779
# Raiders of the Lost Ark (1981)                        2.693297
# Raiders of the Lost Ark (1981)                        2.680586
# Austin Powers: International Man of Mystery (1997)    1.887164
# Sting, The (1973)                                     1.837692
# dtype: float64

# %%
similarCandidates=similarCandidates.groupby(similarCandidates.index).sum()

# %%
similarCandidates.sort_values(inplace=True,ascending=False)
print(similarCandidates.head(10))
# Out:
# Empire Strikes Back, The (1980)              8.877450
# Star Wars (1977)                             8.870971
# Return of the Jedi (1983)                    7.178172
# Raiders of the Lost Ark (1981)               5.519700
# Indiana Jones and the Last Crusade (1989)    3.488028
# Bridge on the River Kwai, The (1957)         3.366616
# Back to the Future (1985)                    3.357941
# Sting, The (1973)                            3.329843
# Cinderella (1950)                            3.245412
# Field of Dreams (1989)                       3.222311
# dtype: float64

# %%
recommendedMovies=similarCandidates.drop(myRatings.index)

# %%
recommendedMovies.head(5)
# Out:
# Return of the Jedi (1983)                    7.178172
# Raiders of the Lost Ark (1981)               5.519700
# Indiana Jones and the Last Crusade (1989)    3.488028
# Bridge on the River Kwai, The (1957)         3.366616
# Back to the Future (1985)                    3.357941
# dtype: float64

# %%
df.head()
# Out:
#                               (rating, size)  (rating, mean)  similarity
# title
# 101 Dalmatians (1996)                    109        2.908257    0.211132
# 12 Angry Men (1957)                      125        4.344000    0.184289
# 2001: A Space Odyssey (1968)             259        3.969112    0.230884
# Absolute Power (1997)                    127        3.370079    0.085440
# Abyss, The (1989)                        151        3.589404    0.203709

# %%
df.sort_values(['similarity'],ascending=False)[:15]
# Out:
#                                                     (rating, size)  \
# title
# Star Wars (1977)                                               584
# Empire Strikes Back, The (1980)                                368
# Return of the Jedi (1983)                                      507
# Raiders of the Lost Ark (1981)                                 420
# Austin Powers: International Man of Mystery (1997)             130
# Sting, The (1973)                                              241
# Indiana Jones and the Last Crusade (1989)                      331
# Pinocchio (1940)                                               101
# Frighteners, The (1996)                                        115
# L.A. Confidential (1997)                                       297
# Wag the Dog (1997)                                             137
# Dumbo (1941)                                                   123
# Bridge on the River Kwai, The (1957)                           165
# ...

# %% [markdown]
# ## here we recommeded movies for user 0 .. we can do it for any user
